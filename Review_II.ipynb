# %% [markdown]
# <a href="https://colab.research.google.com/github/Kabiya2018/IWP/blob/master/Review_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yahoo_fin --upgrade

# %%
pip install requests_html

# %%
import yahoo_fin.stock_info as si
import pandas as pd
import numpy as np

# %%
stock_list = ['ADANIPORTS.NS','ARVIND.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BAJAJFINSV.NS', 'BHARTIARTL.NS', 'BPCL.NS', 'BRITANNIA.NS','CIPLA.NS', 'COALINDIA.NS', 'DIVISLAB.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'GILLETTE.NS', 'GOKEX.NS', 'GRASIM.NS', 'HCLTECH.NS', 'HDFC.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'HINDALCO.NS', 'HINDUNILVR.NS', 'IBREALEST.NS', 'ICICIBANK.NS', 'INDUSINDBK.NS', 'INFY.NS', 'IOC.NS',  'ITC.NS', 'JSWSTEEL.NS', 'KOTAKBANK.NS', 'LT.NS', 'M&M.NS', 'MARUTI.NS', 'NESTLEIND.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'RELIANCE.NS', 'SBIN.NS', 'SBILIFE.NS', 'SHREECEM.NS', 'SUNPHARMA.NS', 'TATAMOTORS.NS', 'TATASTEEL.NS',  'TCS.NS', 'TATACONSUM.NS', 'TECHM.NS', 'TITAN.NS', 'ULTRACEMCO.NS', 'UPL.NS','WIPRO.NS']

# %%
dow_stats = {}
for ticker in stock_list:
    temp = si.get_stats_valuation(ticker)
    temp = temp.iloc[:,:2]
    temp.columns = ["Attribute", "Recent"]
    dow_stats[ticker] = temp
dow_stats
# Out:
# {'ADANIPORTS.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.51T
#  1           Enterprise Value  1.83T
#  2               Trailing P/E  29.46
#  3                Forward P/E  19.61
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   9.82
#  6           Price/Book (mrq)   4.88
#  7   Enterprise Value/Revenue  11.93
#  8    Enterprise Value/EBITDA  16.68,
#  'ARVIND.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  30.46B
#  1           Enterprise Value  49.26B
#  2               Trailing P/E   19.42
#  3                Forward P/E     NaN
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    0.46
#  6           Price/Book (mrq)    1.09
#  7   Enterprise Value/Revenue    0.75
#  8    Enterprise Value/EBITDA    6.76,
#  'ASIANPAINT.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.98T
#  1           Enterprise Value  2.96T
#  2               Trailing P/E  93.71
#  3                Forward P/E  73.53
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  11.77
#  6           Price/Book (mrq)  24.40
#  7   Enterprise Value/Revenue  11.44
#  8    Enterprise Value/EBITDA  55.24,
#  'AXISBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.06T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  20.71
#  3                Forward P/E  11.98
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.46
#  6           Price/Book (mrq)   1.89
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'BAJAJ-AUTO.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  951.13B
#  1           Enterprise Value  879.92B
#  2               Trailing P/E    14.86
#  3                Forward P/E    13.95
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     2.93
#  6           Price/Book (mrq)     3.56
#  7   Enterprise Value/Revenue     2.68
#  8    Enterprise Value/EBITDA    10.56,
#  'BAJAJFINSV.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.78T
#  1           Enterprise Value  3.86T
#  2               Trailing P/E  66.91
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.86
#  6           Price/Book (mrq)   7.46
#  7   Enterprise Value/Revenue   6.64
#  8    Enterprise Value/EBITDA    NaN,
#  'BAJFINANCE.NS':                    Attribute Recent
#  0      Market Cap (intraday)  4.27T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  87.54
#  3                Forward P/E  44.05
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  25.58
#  6           Price/Book (mrq)  11.11
#  7   Enterprise Value/Revenue  10.89
#  8    Enterprise Value/EBITDA    NaN,
#  'BHARTIARTL.NS':                    Attribute Recent
#  0      Market Cap (intraday)  4.22T
#  1           Enterprise Value  5.64T
#  2               Trailing P/E    NaN
#  3                Forward P/E  44.64
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.80
#  6           Price/Book (mrq)   7.16
#  7   Enterprise Value/Revenue   5.25
#  8    Enterprise Value/EBITDA  11.98,
#  'BPCL.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  837.11B
#  1           Enterprise Value    1.24T
#  2               Trailing P/E     4.29
#  3                Forward P/E    12.56
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     0.27
#  6           Price/Book (mrq)     1.70
#  7   Enterprise Value/Revenue     0.43
#  8    Enterprise Value/EBITDA     4.14,
#  'BRITANNIA.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  849.67B
#  1           Enterprise Value  865.96B
#  2               Trailing P/E    53.34
#  3                Forward P/E    52.63
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     6.51
#  6           Price/Book (mrq)    47.14
#  7   Enterprise Value/Revenue     6.64
#  8    Enterprise Value/EBITDA    34.85,
#  'CIPLA.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  748.54B
#  1           Enterprise Value  719.33B
#  2               Trailing P/E    28.74
#  3                Forward P/E    23.31
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     3.59
#  6           Price/Book (mrq)     3.82
#  7   Enterprise Value/Revenue     3.47
#  8    Enterprise Value/EBITDA    15.18,
#  'COALINDIA.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  950.60B
#  1           Enterprise Value  670.50B
#  2               Trailing P/E     6.90
#  3                Forward P/E     6.36
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     1.04
#  6           Price/Book (mrq)     2.36
#  7   Enterprise Value/Revenue     0.74
#  8    Enterprise Value/EBITDA     2.85,
#  'DIVISLAB.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.26T
#  1           Enterprise Value  1.24T
#  2               Trailing P/E  59.37
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  17.31
#  6           Price/Book (mrq)  12.77
#  7   Enterprise Value/Revenue  16.96
#  8    Enterprise Value/EBITDA  39.14,
#  'DRREDDY.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  776.46B
#  1           Enterprise Value  782.15B
#  2               Trailing P/E    39.98
#  3                Forward P/E    28.01
#  4  PEG Ratio (5 yr expected)     1.56
#  5          Price/Sales (ttm)     3.82
#  6           Price/Book (mrq)     4.22
#  7   Enterprise Value/Revenue     3.85
#  8    Enterprise Value/EBITDA    18.49,
#  'EICHERMOT.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  666.66B
#  1           Enterprise Value  624.70B
#  2               Trailing P/E    40.20
#  3                Forward P/E    20.92
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     6.78
#  6           Price/Book (mrq)     5.81
#  7   Enterprise Value/Revenue     6.31
#  8    Enterprise Value/EBITDA    23.31,
#  'GILLETTE.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  175.64B
#  1           Enterprise Value  174.00B
#  2               Trailing P/E    60.69
#  3                Forward P/E      NaN
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     8.72
#  6           Price/Book (mrq)    22.85
#  7   Enterprise Value/Revenue     8.42
#  8    Enterprise Value/EBITDA    35.91,
#  'GOKEX.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  15.61B
#  1           Enterprise Value  20.41B
#  2               Trailing P/E   26.23
#  3                Forward P/E     NaN
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    1.01
#  6           Price/Book (mrq)    5.16
#  7   Enterprise Value/Revenue    1.63
#  8    Enterprise Value/EBITDA   15.71,
#  'GRASIM.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.11T
#  1           Enterprise Value  1.63T
#  2               Trailing P/E  18.21
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.27
#  6           Price/Book (mrq)   1.57
#  7   Enterprise Value/Revenue   1.87
#  8    Enterprise Value/EBITDA   8.60,
#  'HCLTECH.NS':                    Attribute Recent
#  0      Market Cap (intraday)  3.07T
#  1           Enterprise Value  2.92T
#  2               Trailing P/E  26.66
#  3                Forward P/E  23.04
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.86
#  6           Price/Book (mrq)   5.07
#  7   Enterprise Value/Revenue   3.66
#  8    Enterprise Value/EBITDA  13.86,
#  'HDFC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  5.02T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  24.57
#  3                Forward P/E  29.85
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.36
#  6           Price/Book (mrq)   3.11
#  7   Enterprise Value/Revenue   5.10
#  8    Enterprise Value/EBITDA    NaN,
#  'HDFCBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  8.28T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  25.31
#  3                Forward P/E  22.37
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   8.81
#  6           Price/Book (mrq)   3.83
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'HEROMOTOCO.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  494.06B
#  1           Enterprise Value  437.20B
#  2               Trailing P/E    17.03
#  3                Forward P/E    12.52
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     1.54
#  6           Price/Book (mrq)     3.14
#  7   Enterprise Value/Revenue     1.36
#  8    Enterprise Value/EBITDA     9.51,
#  'HINDALCO.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  947.33B
#  1           Enterprise Value    1.43T
#  2               Trailing P/E     9.04
#  3                Forward P/E     6.22
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     0.59
#  6           Price/Book (mrq)     1.35
#  7   Enterprise Value/Revenue     0.87
#  8    Enterprise Value/EBITDA     5.53,
#  'HINDUNILVR.NS':                    Attribute Recent
#  0      Market Cap (intraday)  5.51T
#  1           Enterprise Value  5.44T
#  2               Trailing P/E  66.68
#  3                Forward P/E  52.91
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  11.28
#  6           Price/Book (mrq)  11.68
#  7   Enterprise Value/Revenue  10.96
#  8    Enterprise Value/EBITDA  43.91,
#  'IBREALEST.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  75.38B
#  1           Enterprise Value  76.52B
#  2               Trailing P/E   40.65
#  3                Forward P/E     NaN
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    3.20
#  6           Price/Book (mrq)    2.14
#  7   Enterprise Value/Revenue    3.30
#  8    Enterprise Value/EBITDA   17.24,
#  'ICICIBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  5.05T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  23.95
#  3                Forward P/E  18.08
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.30
#  6           Price/Book (mrq)   2.97
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'INDUSINDBK.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  736.38B
#  1           Enterprise Value      NaN
#  2               Trailing P/E    18.47
#  3                Forward P/E     9.79
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     3.53
#  6           Price/Book (mrq)     1.62
#  7   Enterprise Value/Revenue      NaN
#  8    Enterprise Value/EBITDA      NaN,
#  'INFY.NS':                    Attribute  Recent
#  0      Market Cap (intraday)   7.11T
#  1           Enterprise Value   6.92T
#  2               Trailing P/E   34.50
#  3                Forward P/E   32.47
#  4  PEG Ratio (5 yr expected)    2.70
#  5          Price/Sales (ttm)    6.48
#  6           Price/Book (mrq)   10.13
#  7   Enterprise Value/Revenue  464.37
#  8    Enterprise Value/EBITDA   1.58k,
#  'IOC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.11T
#  1           Enterprise Value  2.06T
#  2               Trailing P/E   4.31
#  3                Forward P/E   6.69
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.24
#  6           Price/Book (mrq)   0.89
#  7   Enterprise Value/Revenue   0.44
#  8    Enterprise Value/EBITDA   3.94,
#  'ITC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.73T
#  1           Enterprise Value  2.54T
#  2               Trailing P/E  19.44
#  3                Forward P/E  16.78
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   5.14
#  6           Price/Book (mrq)   4.56
#  7   Enterprise Value/Revenue   4.70
#  8    Enterprise Value/EBITDA  11.99,
#  'JSWSTEEL.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.56T
#  1           Enterprise Value  2.10T
#  2               Trailing P/E   7.83
#  3                Forward P/E   9.52
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.44
#  6           Price/Book (mrq)   2.57
#  7   Enterprise Value/Revenue   1.94
#  8    Enterprise Value/EBITDA   5.64,
#  'KOTAKBANK.NS':                    Attribute Recent
#  0      Market Cap (intraday)  3.87T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  39.15
#  3                Forward P/E  29.24
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   8.53
#  6           Price/Book (mrq)   4.35
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'LT.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.53T
#  1           Enterprise Value  3.31T
#  2               Trailing P/E  29.01
#  3                Forward P/E  18.12
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.72
#  6           Price/Book (mrq)   3.28
#  7   Enterprise Value/Revenue   2.26
#  8    Enterprise Value/EBITDA  15.68,
#  'M&M.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.06T
#  1           Enterprise Value  1.65T
#  2               Trailing P/E  18.52
#  3                Forward P/E  21.83
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.14
#  6           Price/Book (mrq)   2.45
#  7   Enterprise Value/Revenue   1.99
#  8    Enterprise Value/EBITDA  10.52,
#  'MARUTI.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.18T
#  1           Enterprise Value  2.12T
#  2               Trailing P/E  52.69
#  3                Forward P/E  29.85
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   2.68
#  6           Price/Book (mrq)   4.23
#  7   Enterprise Value/Revenue   2.57
#  8    Enterprise Value/EBITDA  25.86,
#  'NESTLEIND.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.87T
#  1           Enterprise Value  1.85T
#  2               Trailing P/E  83.44
#  3                Forward P/E  69.93
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)  13.04
#  6           Price/Book (mrq)  83.58
#  7   Enterprise Value/Revenue  12.89
#  8    Enterprise Value/EBITDA  51.01,
#  'NTPC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.24T
#  1           Enterprise Value  3.08T
#  2               Trailing P/E   9.31
#  3                Forward P/E   7.62
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.03
#  6           Price/Book (mrq)   0.95
#  7   Enterprise Value/Revenue   2.55
#  8    Enterprise Value/EBITDA   7.83,
#  'ONGC.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.83T
#  1           Enterprise Value  2.87T
#  2               Trailing P/E   5.04
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.47
#  6           Price/Book (mrq)   0.73
#  7   Enterprise Value/Revenue   0.74
#  8    Enterprise Value/EBITDA   3.98,
#  'POWERGRID.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.39T
#  1           Enterprise Value  2.57T
#  2               Trailing P/E   8.67
#  3                Forward P/E  10.81
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.42
#  6           Price/Book (mrq)   1.80
#  7   Enterprise Value/Revenue   6.30
#  8    Enterprise Value/EBITDA   6.25,
#  'RELIANCE.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  16.69T
#  1           Enterprise Value  17.13T
#  2               Trailing P/E   31.07
#  3                Forward P/E   23.36
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    2.83
#  6           Price/Book (mrq)    2.25
#  7   Enterprise Value/Revenue    2.98
#  8    Enterprise Value/EBITDA   15.88,
#  'SBILIFE.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.17T
#  1           Enterprise Value  1.14T
#  2               Trailing P/E  96.28
#  3                Forward P/E  56.50
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.34
#  6           Price/Book (mrq)  10.90
#  7   Enterprise Value/Revenue   1.28
#  8    Enterprise Value/EBITDA    NaN,
#  'SBIN.NS':                    Attribute Recent
#  0      Market Cap (intraday)  4.22T
#  1           Enterprise Value    NaN
#  2               Trailing P/E  14.86
#  3                Forward P/E  10.74
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   1.85
#  6           Price/Book (mrq)   1.46
#  7   Enterprise Value/Revenue    NaN
#  8    Enterprise Value/EBITDA    NaN,
#  'SHREECEM.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  942.41B
#  1           Enterprise Value  925.59B
#  2               Trailing P/E    35.90
#  3                Forward P/E    32.36
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     6.53
#  6           Price/Book (mrq)     5.74
#  7   Enterprise Value/Revenue     6.42
#  8    Enterprise Value/EBITDA    19.14,
#  'SUNPHARMA.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.80T
#  1           Enterprise Value  1.71T
#  2               Trailing P/E  29.58
#  3                Forward P/E  25.64
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   5.18
#  6           Price/Book (mrq)   3.71
#  7   Enterprise Value/Revenue   4.66
#  8    Enterprise Value/EBITDA  18.18,
#  'TATACONSUM.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  712.22B
#  1           Enterprise Value  694.65B
#  2               Trailing P/E    98.07
#  3                Forward P/E    54.35
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     5.87
#  6           Price/Book (mrq)     4.88
#  7   Enterprise Value/Revenue     5.73
#  8    Enterprise Value/EBITDA    45.89,
#  'TATAMOTORS.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.65T
#  1           Enterprise Value  2.42T
#  2               Trailing P/E    NaN
#  3                Forward P/E    NaN
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.67
#  6           Price/Book (mrq)   3.49
#  7   Enterprise Value/Revenue   0.98
#  8    Enterprise Value/EBITDA  12.51,
#  'TATASTEEL.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.38T
#  1           Enterprise Value  2.06T
#  2               Trailing P/E   4.23
#  3                Forward P/E   6.25
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   0.65
#  6           Price/Book (mrq)   1.51
#  7   Enterprise Value/Revenue   1.00
#  8    Enterprise Value/EBITDA   3.61,
#  'TCS.NS':                    Attribute  Recent
#  0      Market Cap (intraday)  12.95T
#  1           Enterprise Value  12.53T
#  2               Trailing P/E   35.56
#  3                Forward P/E   32.47
#  4  PEG Ratio (5 yr expected)    2.62
#  5          Price/Sales (ttm)    7.31
#  6           Price/Book (mrq)   13.36
#  7   Enterprise Value/Revenue    7.04
#  8    Enterprise Value/EBITDA   23.10,
#  'TECHM.NS':                    Attribute Recent
#  0      Market Cap (intraday)  1.54T
#  1           Enterprise Value  1.41T
#  2               Trailing P/E  28.36
#  3                Forward P/E  21.19
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   3.56
#  6           Price/Book (mrq)   6.29
#  7   Enterprise Value/Revenue   3.49
#  8    Enterprise Value/EBITDA  16.69,
#  'TITAN.NS':                    Attribute  Recent
#  0      Market Cap (intraday)   2.10T
#  1           Enterprise Value   2.14T
#  2               Trailing P/E  121.27
#  3                Forward P/E   76.34
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)    8.12
#  6           Price/Book (mrq)   27.25
#  7   Enterprise Value/Revenue    8.21
#  8    Enterprise Value/EBITDA   72.05,
#  'ULTRACEMCO.NS':                    Attribute Recent
#  0      Market Cap (intraday)  2.14T
#  1           Enterprise Value  2.21T
#  2               Trailing P/E  33.64
#  3                Forward P/E  26.88
#  4  PEG Ratio (5 yr expected)    NaN
#  5          Price/Sales (ttm)   4.29
#  6           Price/Book (mrq)   4.65
#  7   Enterprise Value/Revenue   4.41
#  8    Enterprise Value/EBITDA  16.40,
#  'UPL.NS':                    Attribute   Recent
#  0      Market Cap (intraday)  527.57B
#  1           Enterprise Value  771.92B
#  2               Trailing P/E    17.48
#  3                Forward P/E      NaN
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)     1.33
#  6           Price/Book (mrq)     2.44
#  7   Enterprise Value/Revenue     1.90
#  8    Enterprise Value/EBITDA     9.49,
#  'WIPRO.NS':                    Attribute Recent
#  0      Market Cap (intraday)  3.48T
#  1           Enterprise Value  3.30T
#  2               Trailing P/E  29.22
#  3                Forward P/E  28.90
#  4  PEG Ratio (5 yr expected)   1.58
#  5          Price/Sales (ttm)   5.06
#  6           Price/Book (mrq)   5.60
#  7   Enterprise Value/Revenue   4.72
#  8    Enterprise Value/EBITDA  21.14}

# %%
combined_stats = pd.concat(dow_stats)
combined_stats = combined_stats.reset_index()
combined_stats
# Out:
#            level_0  level_1                  Attribute Recent
# 0    ADANIPORTS.NS        0      Market Cap (intraday)  1.51T
# 1    ADANIPORTS.NS        1           Enterprise Value  1.83T
# 2    ADANIPORTS.NS        2               Trailing P/E  29.46
# 3    ADANIPORTS.NS        3                Forward P/E  19.61
# 4    ADANIPORTS.NS        4  PEG Ratio (5 yr expected)    NaN
# ..             ...      ...                        ...    ...
# 472       WIPRO.NS        4  PEG Ratio (5 yr expected)   1.58
# 473       WIPRO.NS        5          Price/Sales (ttm)   5.06
# 474       WIPRO.NS        6           Price/Book (mrq)   5.60
# 475       WIPRO.NS        7   Enterprise Value/Revenue   4.72
# 476       WIPRO.NS        8    Enterprise Value/EBITDA  21.14
#
# [477 rows x 4 columns]

# %%
del combined_stats["level_1"]
# update column names
combined_stats.columns = ["Ticker", "Attribute", "Recent"]
combined_stats
# Out:
#             Ticker                  Attribute Recent
# 0    ADANIPORTS.NS      Market Cap (intraday)  1.51T
# 1    ADANIPORTS.NS           Enterprise Value  1.83T
# 2    ADANIPORTS.NS               Trailing P/E  29.46
# 3    ADANIPORTS.NS                Forward P/E  19.61
# 4    ADANIPORTS.NS  PEG Ratio (5 yr expected)    NaN
# ..             ...                        ...    ...
# 472       WIPRO.NS  PEG Ratio (5 yr expected)   1.58
# 473       WIPRO.NS          Price/Sales (ttm)   5.06
# 474       WIPRO.NS           Price/Book (mrq)   5.60
# 475       WIPRO.NS   Enterprise Value/Revenue   4.72
# 476       WIPRO.NS    Enterprise Value/EBITDA  21.14
#
# [477 rows x 3 columns]

# %%
markcap = combined_stats[combined_stats["Attribute"]=="Market Cap (intraday)"].reset_index()
markcap
# Out:
#     index         Ticker              Attribute   Recent
# 0       0  ADANIPORTS.NS  Market Cap (intraday)    1.51T
# 1       9      ARVIND.NS  Market Cap (intraday)   30.46B
# 2      18  ASIANPAINT.NS  Market Cap (intraday)    2.98T
# 3      27    AXISBANK.NS  Market Cap (intraday)    2.06T
# 4      36  BAJAJ-AUTO.NS  Market Cap (intraday)  951.13B
# 5      45  BAJFINANCE.NS  Market Cap (intraday)    4.27T
# 6      54  BAJAJFINSV.NS  Market Cap (intraday)    2.78T
# 7      63  BHARTIARTL.NS  Market Cap (intraday)    4.22T
# 8      72        BPCL.NS  Market Cap (intraday)  837.11B
# 9      81   BRITANNIA.NS  Market Cap (intraday)  849.67B
# 10     90       CIPLA.NS  Market Cap (intraday)  748.54B
# 11     99   COALINDIA.NS  Market Cap (intraday)  950.60B
# 12    108    DIVISLAB.NS  Market Cap (intraday)    1.26T
# 13    117     DRREDDY.NS  Market Cap (intraday)  776.46B
# 14    126   EICHERMOT.NS  Market Cap (intraday)  666.66B
# 15    135    GILLETTE.NS  Market Cap (intraday)  175.64B
# 16    144       GOKEX.NS  Market Cap (intraday)   15.61B
# 17    153      GRASIM.NS  Market Cap (intraday)    1.11T
# 18    162     HCLTECH.NS  Market Cap (intraday)    3.07T
# 19    171        HDFC.NS  Market Cap (intraday)    5.02T
# 20    180    HDFCBANK.NS  Market Cap (intraday)    8.28T
# 21    189  HEROMOTOCO.NS  Market Cap (intraday)  494.06B
# 22    198    HINDALCO.NS  Market Cap (intraday)  947.33B
# 23    207  HINDUNILVR.NS  Market Cap (intraday)    5.51T
# 24    216   IBREALEST.NS  Market Cap (intraday)   75.38B
# 25    225   ICICIBANK.NS  Market Cap (intraday)    5.05T
# 26    234  INDUSINDBK.NS  Market Cap (intraday)  736.38B
# 27    243        INFY.NS  Market Cap (intraday)    7.11T
# 28    252         IOC.NS  Market Cap (intraday)    1.11T
# 29    261         ITC.NS  Market Cap (intraday)    2.73T
# 30    270    JSWSTEEL.NS  Market Cap (intraday)    1.56T
# 31    279   KOTAKBANK.NS  Market Cap (intraday)    3.87T
# 32    288          LT.NS  Market Cap (intraday)    2.53T
# 33    297         M&M.NS  Market Cap (intraday)    1.06T
# 34    306      MARUTI.NS  Market Cap (intraday)    2.18T
# 35    315   NESTLEIND.NS  Market Cap (intraday)    1.87T
# 36    324        NTPC.NS  Market Cap (intraday)    1.24T
# 37    333        ONGC.NS  Market Cap (intraday)    1.83T
# 38    342   POWERGRID.NS  Market Cap (intraday)    1.39T
# 39    351    RELIANCE.NS  Market Cap (intraday)   16.69T
# 40    360        SBIN.NS  Market Cap (intraday)    4.22T
# 41    369     SBILIFE.NS  Market Cap (intraday)    1.17T
# 42    378    SHREECEM.NS  Market Cap (intraday)  942.41B
# 43    387   SUNPHARMA.NS  Market Cap (intraday)    1.80T
# 44    396  TATAMOTORS.NS  Market Cap (intraday)    1.65T
# 45    405   TATASTEEL.NS  Market Cap (intraday)    1.38T
# 46    414         TCS.NS  Market Cap (intraday)   12.95T
# 47    423  TATACONSUM.NS  Market Cap (intraday)  712.22B
# 48    432       TECHM.NS  Market Cap (intraday)    1.54T
# 49    441       TITAN.NS  Market Cap (intraday)    2.10T
# 50    450  ULTRACEMCO.NS  Market Cap (intraday)    2.14T
# 51    459         UPL.NS  Market Cap (intraday)  527.57B
# 52    468       WIPRO.NS  Market Cap (intraday)    3.48T

# %%
del markcap["index"]

# %%
del markcap["Attribute"]
markcap.columns = ["Ticker", "Market Cap"]
markcap
# Out:
#            Ticker Market Cap
# 0   ADANIPORTS.NS      1.51T
# 1       ARVIND.NS     30.46B
# 2   ASIANPAINT.NS      2.98T
# 3     AXISBANK.NS      2.06T
# 4   BAJAJ-AUTO.NS    951.13B
# 5   BAJFINANCE.NS      4.27T
# 6   BAJAJFINSV.NS      2.78T
# 7   BHARTIARTL.NS      4.22T
# 8         BPCL.NS    837.11B
# 9    BRITANNIA.NS    849.67B
# 10       CIPLA.NS    748.54B
# 11   COALINDIA.NS    950.60B
# 12    DIVISLAB.NS      1.26T
# 13     DRREDDY.NS    776.46B
# 14   EICHERMOT.NS    666.66B
# 15    GILLETTE.NS    175.64B
# 16       GOKEX.NS     15.61B
# 17      GRASIM.NS      1.11T
# 18     HCLTECH.NS      3.07T
# 19        HDFC.NS      5.02T
# 20    HDFCBANK.NS      8.28T
# 21  HEROMOTOCO.NS    494.06B
# 22    HINDALCO.NS    947.33B
# 23  HINDUNILVR.NS      5.51T
# 24   IBREALEST.NS     75.38B
# 25   ICICIBANK.NS      5.05T
# 26  INDUSINDBK.NS    736.38B
# 27        INFY.NS      7.11T
# 28         IOC.NS      1.11T
# 29         ITC.NS      2.73T
# 30    JSWSTEEL.NS      1.56T
# 31   KOTAKBANK.NS      3.87T
# 32          LT.NS      2.53T
# 33         M&M.NS      1.06T
# 34      MARUTI.NS      2.18T
# 35   NESTLEIND.NS      1.87T
# 36        NTPC.NS      1.24T
# 37        ONGC.NS      1.83T
# 38   POWERGRID.NS      1.39T
# 39    RELIANCE.NS     16.69T
# 40        SBIN.NS      4.22T
# 41     SBILIFE.NS      1.17T
# 42    SHREECEM.NS    942.41B
# 43   SUNPHARMA.NS      1.80T
# 44  TATAMOTORS.NS      1.65T
# 45   TATASTEEL.NS      1.38T
# 46         TCS.NS     12.95T
# 47  TATACONSUM.NS    712.22B
# 48       TECHM.NS      1.54T
# 49       TITAN.NS      2.10T
# 50  ULTRACEMCO.NS      2.14T
# 51         UPL.NS    527.57B
# 52       WIPRO.NS      3.48T

# %%
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(lambda x: x.str.replace('.','', regex=True))
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(lambda x: x.str.replace('T','0000000000', regex=True))
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(lambda x: x.str.replace('B','0000000', regex=True))
markcap
# Out:
#            Ticker      Market Cap
# 0   ADANIPORTS.NS   1510000000000
# 1       ARVIND.NS     30460000000
# 2   ASIANPAINT.NS   2980000000000
# 3     AXISBANK.NS   2060000000000
# 4   BAJAJ-AUTO.NS    951130000000
# 5   BAJFINANCE.NS   4270000000000
# 6   BAJAJFINSV.NS   2780000000000
# 7   BHARTIARTL.NS   4220000000000
# 8         BPCL.NS    837110000000
# 9    BRITANNIA.NS    849670000000
# 10       CIPLA.NS    748540000000
# 11   COALINDIA.NS    950600000000
# 12    DIVISLAB.NS   1260000000000
# 13     DRREDDY.NS    776460000000
# 14   EICHERMOT.NS    666660000000
# 15    GILLETTE.NS    175640000000
# 16       GOKEX.NS     15610000000
# 17      GRASIM.NS   1110000000000
# 18     HCLTECH.NS   3070000000000
# 19        HDFC.NS   5020000000000
# 20    HDFCBANK.NS   8280000000000
# 21  HEROMOTOCO.NS    494060000000
# 22    HINDALCO.NS    947330000000
# 23  HINDUNILVR.NS   5510000000000
# 24   IBREALEST.NS     75380000000
# 25   ICICIBANK.NS   5050000000000
# 26  INDUSINDBK.NS    736380000000
# 27        INFY.NS   7110000000000
# 28         IOC.NS   1110000000000
# 29         ITC.NS   2730000000000
# 30    JSWSTEEL.NS   1560000000000
# 31   KOTAKBANK.NS   3870000000000
# 32          LT.NS   2530000000000
# 33         M&M.NS   1060000000000
# 34      MARUTI.NS   2180000000000
# 35   NESTLEIND.NS   1870000000000
# 36        NTPC.NS   1240000000000
# 37        ONGC.NS   1830000000000
# 38   POWERGRID.NS   1390000000000
# 39    RELIANCE.NS  16690000000000
# 40        SBIN.NS   4220000000000
# 41     SBILIFE.NS   1170000000000
# 42    SHREECEM.NS    942410000000
# 43   SUNPHARMA.NS   1800000000000
# 44  TATAMOTORS.NS   1650000000000
# 45   TATASTEEL.NS   1380000000000
# 46         TCS.NS  12950000000000
# 47  TATACONSUM.NS    712220000000
# 48       TECHM.NS   1540000000000
# 49       TITAN.NS   2100000000000
# 50  ULTRACEMCO.NS   2140000000000
# 51         UPL.NS    527570000000
# 52       WIPRO.NS   3480000000000

# %%
markcap[["Market Cap"]] = markcap[["Market Cap"]].apply(pd.to_numeric)
markcap
# Out:
#            Ticker      Market Cap
# 0   ADANIPORTS.NS   1510000000000
# 1       ARVIND.NS     30460000000
# 2   ASIANPAINT.NS   2980000000000
# 3     AXISBANK.NS   2060000000000
# 4   BAJAJ-AUTO.NS    951130000000
# 5   BAJFINANCE.NS   4270000000000
# 6   BAJAJFINSV.NS   2780000000000
# 7   BHARTIARTL.NS   4220000000000
# 8         BPCL.NS    837110000000
# 9    BRITANNIA.NS    849670000000
# 10       CIPLA.NS    748540000000
# 11   COALINDIA.NS    950600000000
# 12    DIVISLAB.NS   1260000000000
# 13     DRREDDY.NS    776460000000
# 14   EICHERMOT.NS    666660000000
# 15    GILLETTE.NS    175640000000
# 16       GOKEX.NS     15610000000
# 17      GRASIM.NS   1110000000000
# 18     HCLTECH.NS   3070000000000
# 19        HDFC.NS   5020000000000
# 20    HDFCBANK.NS   8280000000000
# 21  HEROMOTOCO.NS    494060000000
# 22    HINDALCO.NS    947330000000
# 23  HINDUNILVR.NS   5510000000000
# 24   IBREALEST.NS     75380000000
# 25   ICICIBANK.NS   5050000000000
# 26  INDUSINDBK.NS    736380000000
# 27        INFY.NS   7110000000000
# 28         IOC.NS   1110000000000
# 29         ITC.NS   2730000000000
# 30    JSWSTEEL.NS   1560000000000
# 31   KOTAKBANK.NS   3870000000000
# 32          LT.NS   2530000000000
# 33         M&M.NS   1060000000000
# 34      MARUTI.NS   2180000000000
# 35   NESTLEIND.NS   1870000000000
# 36        NTPC.NS   1240000000000
# 37        ONGC.NS   1830000000000
# 38   POWERGRID.NS   1390000000000
# 39    RELIANCE.NS  16690000000000
# 40        SBIN.NS   4220000000000
# 41     SBILIFE.NS   1170000000000
# 42    SHREECEM.NS    942410000000
# 43   SUNPHARMA.NS   1800000000000
# 44  TATAMOTORS.NS   1650000000000
# 45   TATASTEEL.NS   1380000000000
# 46         TCS.NS  12950000000000
# 47  TATACONSUM.NS    712220000000
# 48       TECHM.NS   1540000000000
# 49       TITAN.NS   2100000000000
# 50  ULTRACEMCO.NS   2140000000000
# 51         UPL.NS    527570000000
# 52       WIPRO.NS   3480000000000

# %%
markcap['Class'] = np.where(markcap['Market Cap'] >= 200000000000, 'Large-cap', 'Mid-cap')
markcap
# Out:
#            Ticker      Market Cap      Class
# 0   ADANIPORTS.NS   1510000000000  Large-cap
# 1       ARVIND.NS     30460000000    Mid-cap
# 2   ASIANPAINT.NS   2980000000000  Large-cap
# 3     AXISBANK.NS   2060000000000  Large-cap
# 4   BAJAJ-AUTO.NS    951130000000  Large-cap
# 5   BAJFINANCE.NS   4270000000000  Large-cap
# 6   BAJAJFINSV.NS   2780000000000  Large-cap
# 7   BHARTIARTL.NS   4220000000000  Large-cap
# 8         BPCL.NS    837110000000  Large-cap
# 9    BRITANNIA.NS    849670000000  Large-cap
# 10       CIPLA.NS    748540000000  Large-cap
# 11   COALINDIA.NS    950600000000  Large-cap
# 12    DIVISLAB.NS   1260000000000  Large-cap
# 13     DRREDDY.NS    776460000000  Large-cap
# 14   EICHERMOT.NS    666660000000  Large-cap
# 15    GILLETTE.NS    175640000000    Mid-cap
# 16       GOKEX.NS     15610000000    Mid-cap
# 17      GRASIM.NS   1110000000000  Large-cap
# 18     HCLTECH.NS   3070000000000  Large-cap
# 19        HDFC.NS   5020000000000  Large-cap
# 20    HDFCBANK.NS   8280000000000  Large-cap
# 21  HEROMOTOCO.NS    494060000000  Large-cap
# 22    HINDALCO.NS    947330000000  Large-cap
# 23  HINDUNILVR.NS   5510000000000  Large-cap
# 24   IBREALEST.NS     75380000000    Mid-cap
# 25   ICICIBANK.NS   5050000000000  Large-cap
# 26  INDUSINDBK.NS    736380000000  Large-cap
# 27        INFY.NS   7110000000000  Large-cap
# 28         IOC.NS   1110000000000  Large-cap
# 29         ITC.NS   2730000000000  Large-cap
# 30    JSWSTEEL.NS   1560000000000  Large-cap
# 31   KOTAKBANK.NS   3870000000000  Large-cap
# 32          LT.NS   2530000000000  Large-cap
# 33         M&M.NS   1060000000000  Large-cap
# 34      MARUTI.NS   2180000000000  Large-cap
# 35   NESTLEIND.NS   1870000000000  Large-cap
# 36        NTPC.NS   1240000000000  Large-cap
# 37        ONGC.NS   1830000000000  Large-cap
# 38   POWERGRID.NS   1390000000000  Large-cap
# 39    RELIANCE.NS  16690000000000  Large-cap
# 40        SBIN.NS   4220000000000  Large-cap
# 41     SBILIFE.NS   1170000000000  Large-cap
# 42    SHREECEM.NS    942410000000  Large-cap
# 43   SUNPHARMA.NS   1800000000000  Large-cap
# 44  TATAMOTORS.NS   1650000000000  Large-cap
# 45   TATASTEEL.NS   1380000000000  Large-cap
# 46         TCS.NS  12950000000000  Large-cap
# 47  TATACONSUM.NS    712220000000  Large-cap
# 48       TECHM.NS   1540000000000  Large-cap
# 49       TITAN.NS   2100000000000  Large-cap
# 50  ULTRACEMCO.NS   2140000000000  Large-cap
# 51         UPL.NS    527570000000  Large-cap
# 52       WIPRO.NS   3480000000000  Large-cap
